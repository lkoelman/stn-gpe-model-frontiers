# %% [markdown]
# # Reproducibility info
#
# Print information required to reproduce results of this notebook

# %%
# Enable interactive plots with backend 'notebook'
# %matplotlib notebook

# Enable connecting with ipyton console --existing
# %connect_info

# print code version (hash of checked out version)
# !git log -1

# print date and time of script execution
import datetime
print("\nNotebook executed at at {} in following directory:".format(datetime.datetime.now()))
# %pwd

# %% [markdown]
# ## Fold STN model
#
# Build the Gillies & Willshaw STN model

# %%
from reducemodel.reduce_cell import *
fold_gillies_marasco()

# %% [markdown]
# Inspect model in NEURON GUI

# %%
# inspect the model (this pops up a GUI window outside browser)
from neuron import gui

# Select Tools > Impedance > log(A) > 'Plot' button > plot desired quantities

# %% [markdown]
# # Analyze model

# %% [markdown]
# Voltage attenuation (log scale / dB)
#
# ![electrotonic_25Hz_logA_nogdisabled.png](attachment:electrotonic_25Hz_logA_nogdisabled.png)

# %% [markdown]
# Voltage attenuation (linear scale)
#
# ![electrotonic_25Hz_Vratio_nogdisabled.png](attachment:electrotonic_25Hz_Vratio_nogdisabled.png)

# %% [markdown]
# Input impedance
#
# ![electrotonic_25Hz_Zin_nogdisabled.png](attachment:electrotonic_25Hz_Zin_nogdisabled.png)

# %% [markdown]
# Transfer impedance
#
# ![electrotonic_25Hz_Ztransfer_nogdisabled.png](attachment:electrotonic_25Hz_Ztransfer_nogdisabled.png)
